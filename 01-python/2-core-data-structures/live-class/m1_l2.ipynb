# %%
# student1 = "Aarav"
# student2 = "Priya"
# student3 = "Ravi"

# print(student1)
# print(student2)
# print(student3)


students = ["Aarav", "Priya","Ravi", 'Priya']
stdents_from_class_b = ['Nisha', 'Tina', 'Kapil', 'Aarav'];
# students[2] = 'Tanishq' # replace
# Add Last
students.extend(stdents_from_class_b)
# students.append('Ritesh')
# students.append('Shaan')
# Add at index
# students.insert(3, 'Offical Ankit Rajak')

# students.remove[3]
students.remove('Aarav');
students.pop()
del students[3]
print(students[0][0:3])
# print(students[2])

name = 'Ritesh'
name = name.join(' ').join('Firodiya')
print(name)
# print(students[2])
# print(students[4])
# print(students[5])
# Out:
# Pri
# F i r o d i y a

# %%
students = [10, 2, 3, 7, 5, 4];
# students = ['Nisha', 'Tina', 'Kapil'];
new = students.sort()
print(students)
print(new)


original = [3, 1, 2]
new      = sorted(original)    # returns a NEW sorted list
print(original)                # [3, 1, 2]   — unchanged!
print(new)                     # [1, 2, 3]
# Out:
# [2, 3, 4, 5, 7, 10]
# None
# [3, 1, 2]
# [1, 2, 3]

# %%
students = ["Aarav", "Priya","Ravi", 'Priya']
students_from_class_b = ['Nisha', 'Tina', 'Kapil', 'Aarav'];

students.extend(students_from_class_b);

print('Randeepkauor' in students)
print('Aarav' in students)

print(students.count('Priya'))

print(type(students))    # <class 'list'>
# Out:
# False
# True
# 2
# <class 'list'>

# %%
coordinates  = (28.6139, 77.2090)        # latitude, longitude — Delhi
rgb_red      = (255, 0, 0)               # an RGB colour
student_info = ("Priya", 20, "Math", 'address', 'country', 'state', 'phone')     # a fixed record
students1 = []
students2 = []

students1.extend(student_info);
print(students1);
students2.append(student_info);
print(students2);
# student_info[0] = 'Riya';

print(student_info[0])     # Priya
print(student_info[-1])    # Math
print(student_info[0:2])   # ('Priya', 20)
print(len(student_info))   # 3
# Out:
# ['Priya', 20, 'Math', 'address', 'country', 'state', 'phone']
# [('Priya', 20, 'Math', 'address', 'country', 'state', 'phone')]
# Priya
# phone
# ('Priya', 20)
# 7

# %%
# Tuple → list (so you can modify)
days_tuple = (
    "Mon", "Tue", "Wed", "Thu", "Fri",
    # Weekend
    [ 'Sat', 'Sunday']
    )
days_list  = list(days_tuple)
days_list.append("Sat")
# print(days_list)              # ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat']

# List → tuple (so it can't be modified)
cart = ["Ritesh", "30", "Male", 'Pune']
final_order = tuple(cart)
# print(final_order)            # ('shirt', 'jeans', 'shoes')

# name = final_order[0]
# age = final_order[1]
# gender = final_order[2]
name, age, gender, city = final_order;

print(f"Hi {name}!, Whose Gender is {gender} and age is {age} from {city}")
# Out:
# Hi Ritesh!, Whose Gender is Male and age is 30 from Pune

# %%
weekends = [ 'Sat', 'Sunday'];
days_tuple = (
   ("Mon", "Tue", "Wed", "Thu", "Fri"),
    # Weekend
    tuple(weekends)
    )
weekends = 'xyz'
# weekends.append('Sunday 2')
day1, day2, = days_tuple
print(f"Weekends: {day2}")
# Out:
# Weekends: ('Sat', 'Sunday')
