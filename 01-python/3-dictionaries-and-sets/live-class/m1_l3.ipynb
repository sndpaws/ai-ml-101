# %%
list = ["Maths", "Physics", "Chemistry", "Biology", "English"]
print(list[::3])

# %%
mixed = ["Aarav", 22, True, 3.14, ]
mixed1 = ["Aarav", 22, True, 3.14, ]
subjects = ["Maths", "Physics", "Chemistry", "Biology", "English"];
mixed.append(subjects)
mixed1.extend(subjects)
print(mixed)
print(mixed1)

# print(mixed[0], type(mixed[0]))
# print(mixed[1], type(mixed[1]))
# print(mixed[2], type(mixed[2]))
# print(mixed[3], type(mixed[3]))

for item in mixed1:
  print(item, type(item))

# %%
subjects = ["Maths", "Physics", "Chemistry", "Biology", "English", 'Geography'];
student1 = ('Aarav', 55, 36, 42, 48, 51)
student2 = (65, 46, 52, 38, 41, 'Arushi')

# print(f'Name: {student1[0]}')
# print(f'Maths: {student1[1]}')
# print(f'Physics: {student1[2]}')
# print(f'Chemistry: {student1[3]}')
# print(f'Biology: {student1[4]}')
# print(f'English: {student1[5]}')


# dict
student3 = {
    # key: value
    # key is always string, and Unique
    # value is python data structure: int, str, bool, float, list, tupple, dict, set
    'userInfo': {
      'name': 'Ritesh',
      'DOB': [15, 8, 1995],
    },
    'marks': {
      'Chemistry': {
          'has_given_exam': True,
          'marks': 60,
      },
      'English': 36,
      'Physics': 41,
      'Math': 54,
      'Biology': {
          'was_absent': True
      }
    }
}


# Access
print(f'Name: {student3['userInfo']['name']}')
print(f'Maths: {student3['marks']['Math']}')
print(f'Physics: {student3['marks']['Physics']}')
print(f'Chemistry: {student3['marks']['Chemistry']}')
# print(f'Biology: {student3['marks']['Biology']}')
print(f'English: {student3['marks']['English']}')

# What if something is missing ?
print(f'Biology: {student3['marks'].get('Biology', 'Abset')}')

# What if I want keys only ?
print(student3['userInfo'].keys())
# Wha if I want all the values ?
print(student3['marks'].values())

students_marks = [
    # Same lines

    {'userInfo': {'name': 'Y'}, 'marks': {'physics': 30}, 'absent': ['english']},
    {'userInfo': {'name': 'Z'}, 'marks': {'english': 41}, 'absent': ['physics']},
]
# Delete
del student3['marks']['Math']
print(student3)

# Add
student3['marks']['Biology'] = 97
student3['marks']['Biology'] = 47
student3['marks']['English'] = 63
student3['address'] = {
    'city': 'Pune',
    'Pin': 41101
}
print(student3['marks'])
print(student3)

# %%
# Tuple (81, 81, 82, 84) Allows repeation, Immutable, index
# Set {81, 82, 84} // Unique, mutable,

set1 = { 1, 200, 5, 4, 200, 5, 1, 97}
set2 = set()
set2.add(True)
set2.add(False)
set2.add(0)
set2.add(1)
set2.add('1')
set2.add(1.45)
set2.update(set1)
# print(set1)
# set1.add(97)
# set1.add(96)
# print(set1)
# set1.discard(201)
# set1.remove(4)
print(set2)
print(len(set2))

# %%
list =  [1, 200, 5, 4, (200, 1), 5, 1,]

set1 = set(list)
print(set1)
print(len(set1))

# %%
# Items

grades = {
    "Rahul": 85,
    "Priya": 92,
    "Amit":  78,
}

# print(grades.items())
# for items in grades.items():
#   print(f'Name: {items[0]}, Marks: {items[1]}')

student_marks = [
    # Same lines
    {'userInfo': {'name': 'Y'}, 'marks': {'physics': 30, 'english': 41}},
    {'userInfo': {'name': 'Z'}, 'marks': {'physics': 30, 'english': 41}},
    {'userInfo': {'name': 'A'}, 'marks': {'physics': 30, 'english': 41}},
    {'userInfo': {'name': 'B'}, 'marks': {'physics': 30, 'english': 41}},
    {'userInfo': {'name': 'B'}, 'marks': {'physics': 30, 'english': 41}},
    {'userInfo': {'name': 'B'}, 'marks': {'physics': 30, 'english': 41}},
    {'userInfo': {'name': 'B'}, 'marks': {'physics': 30, 'english': 41}},
    {'userInfo': {'name': 'B'}, 'marks': {'physics': 30, 'english': 41}},
    {'userInfo': {'name': 'B'}, 'marks': {'physics': 30, 'english': 41}},
    {'userInfo': {'name': 'B'}, 'marks': {'physics': 30, 'english': 41}},
    {'userInfo': {'name': 'B'}, 'marks': {'physics': 30, 'english': 41}},
    {'userInfo': {'name': 'B'}, 'marks': {'physics': 30, 'english': 41}},
    {'userInfo': {'name': 'B'}, 'marks': {'physics': 30, 'english': 41}},
    {'userInfo': {'name': 'B'}, 'marks': {'physics': 30, 'english': 41}},
    {'userInfo': {'name': 'B'}, 'marks': {'physics': 30, 'english': 41}},
    {'userInfo': {'name': 'B'}, 'marks': {'physics': 30, 'english': 41}},
    {'userInfo': {'name': 'B'}, 'marks': {'physics': 30, 'english': 41}},
    {'userInfo': {'name': 'B'}, 'marks': {'physics': 30, 'english': 41}},
    {'userInfo': {'name': 'B'}, 'marks': {'physics': 30, 'english': 41}},
    {'userInfo': {'name': 'B'}, 'marks': {'physics': 30, 'english': 41}},
    {'userInfo': {'name': 'B'}, 'marks': {'physics': 30, 'english': 41}},
    {'userInfo': {'name': 'B'}, 'marks': {'physics': 30, 'english': 41}},
    {'userInfo': {'name': 'B'}, 'marks': {'physics': 30, 'english': 41}},
]

for student in student_marks:
  name = student['userInfo']['name']
  subject_marks = student['marks'];
  for marks in subject_marks.items():
      subject = marks[0];
      mark = marks[1]
      print(f'Name: {name}, Subject: {subject}, Marks: {mark}')

# %%
ai_students  = {"Rahul", "Priya", "Amit", (1, 2, 'X')}
web_students = {"Amit",  "Neha",  "Rahul", (1, 2, 'X')}

# Union
set3 = ai_students | web_students
# print(set3)

# print(ai_students)
# ai_students.update(web_students)
# print(ai_students)

# Intersection
print(ai_students & web_students)

# Difference from first set
print(ai_students - web_students)

# Different in both sets
print(ai_students ^ web_students)
# a^b  = (a-b) | (b-a)

# %%
list = [1,2,4,3,2,3,4,45,34,34,232,24,3];
f_set = frozenset(list)
print(f_set)
# f_set.add(100) Error
