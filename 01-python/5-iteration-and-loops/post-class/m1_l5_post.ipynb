# %%
# Loop
  # Part of code that we want to do again and again for a variery of input
  # Input can be list, set, tuple, dict, a range of number

# { key: value }
# .keys() = keys
# .values() = values
# .items() = key, value together mapped using tuple
  # dict  .items
  #  .items for tuple
  #   becuase we want both key and value together


# for in : fix set of input, same operation for all input
# range
# while : no fix set of input or we have conditon for closure
  # break: closing the operation
  # continue
    # skips few steps
# Out:
# 1 goes to coutner 1
# 2 goes to coutner 2
# 3rd goes to coutner 3
# 4th goes to coutner 1
# 5th goes to coutner 2
# 6 goes to coutner 3
# 7 goes to coutner 1
# 8 goes to coutner 2
# 9 goes to coutner 3
# 10 goes to coutner 1

# %%
# len, index: positon of element from start starting from 0
# counters = [1, 2, 3]
# passengers = ["1", "2", "3rd", "4th", '5th', 6, 7, 8, 9, 10];
# for index, passanger in enumerate(passengers):
#   # 0, 1, 2, 3, 4,5
#   counter = int(index % len(counters))
#   print(f'{passanger} goes to coutner {counter + 1}');


# you have 50 students in your class,
# you want to break them in 5 batches of 10 students each by roll number
students  = {'Ritesh', 'Priya', ' Madhu', ' Gayatri', 'Ritesh'};
batch_size = 2;
for data in enumerate(students):
  print(data)
  i, roll_number = data
  batch_number = (i // batch_size) + 1;
  print('Student ', roll_number, 'goes to batch no', batch_number)
# Out:
# (0, 'Ritesh')
# Student  Ritesh goes to batch no 1
# (1, ' Gayatri')
# Student   Gayatri goes to batch no 1
# (2, 'Priya')
# Student  Priya goes to batch no 2
# (3, ' Madhu')
# Student   Madhu goes to batch no 2
