# %%
name = "  aisha khan  "

# print(name.upper())              # "  AISHA KHAN  "
# print(name.lower())              # "  aisha khan  "
# print(name.strip())              # "Aisha Khan"  — removes outer whitespace
name = name.replace("aisha","Priya")   # "  Priya Khan
# print(name.find("Khan"))         # 8 — index where 'Khan' starts
# print(name.split(" "))

full_name = name.strip().split(' ');
print(full_name)
first_name = full_name[0];
last_name = full_name[1];
print(first_name[0].upper(), last_name[0].upper())
# Out:
# ['Priya', 'khan']
# P K

# %%
a= """42a"""
# print(a.isdigit())
# print(a.isalpha())

# "hello".startswith("he")

b = 'hello';
c = 'he';

b.startswith(c)
# Out:
# True

# %%
name = "Aisha"
age = 21
greeting = f"Hi {name}, you are {age} years old"
print(greeting)
# Out:
# Hi Aisha, you are 21 years old

# %%
name = 'Ritesh'
print(name[::5])
# Out:
# Rh

# %%
s = "I love Java a lot"
print(s.replace('Java', 'Python'))
# Out:
# I love Python a lot

# %%
text = "neural networks are powerful"
# vovel = aeiou

print(f"vovel count {text.count('a') + text.count('e') + text.count('i') + text.count('0') + text.count('u')}")
# Out:
# vovel count 8

# %%
first_name = "Ritesh"
last_name = "Firodiya"
city = "Bangalore"

full_name = f'{first_name} {last_name}'
print("=" * 30)
print(" " * 9 + " INTRODUCTION" + " " * 9 )
print("=" * 30)
print(f'Name     : {full_name}')
print(f'Initials : {first_name[0]} {last_name[0]}')
print(f'City     : {city}')
print(f'Length   : {len(full_name)} characters')
print("=" * 30)
# Out:
# ...
#           INTRODUCTION
# ...
# Name     : Ritesh Firodiya
# Initials : R F
# City     : Bangalore
# Length   : 15 characters
# ...
